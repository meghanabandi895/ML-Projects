# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as mlt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
df = pd.read_csv("placementdata.csv")
df
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0             1   7.5            1         1                         1
# 1             2   8.9            0         3                         2
# 2             3   7.3            1         2                         2
# 3             4   7.5            1         1                         2
# 4             5   8.3            1         2                         2
# ...         ...   ...          ...       ...                       ...
# 9995       9996   7.5            1         1                         2
# 9996       9997   7.4            0         1                         0
# 9997       9998   8.4            1         3                         0
# 9998       9999   8.9            0         3                         2
# 9999      10000   8.4            0         1                         1
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# ...

# %%
df.head(5)
# Out:
#    StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0          1   7.5            1         1                         1
# 1          2   8.9            0         3                         2
# 2          3   7.3            1         2                         2
# 3          4   7.5            1         1                         2
# 4          5   8.3            1         2                         2
#
#    AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# 0                 65               4.4                        No
# 1                 90               4.0                       Yes
# 2                 82               4.8                       Yes
# 3                 85               4.4                       Yes
# 4                 86               4.5                       Yes
#
#   PlacementTraining  SSC_Marks  HSC_Marks PlacementStatus
# 0                No         61         79       NotPlaced
# ...

# %%
df.tail()
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 9995       9996   7.5            1         1                         2
# 9996       9997   7.4            0         1                         0
# 9997       9998   8.4            1         3                         0
# 9998       9999   8.9            0         3                         2
# 9999      10000   8.4            0         1                         1
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# 9995                 72               3.9                       Yes
# 9996                 90               4.8                        No
# 9997                 70               4.8                       Yes
# 9998                 87               4.8                       Yes
# 9999                 66               3.8                        No
#
#      PlacementTraining  SSC_Marks  HSC_Marks PlacementStatus
# 9995                No         85         66       NotPlaced
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  10000 non-null  int64
#  1   CGPA                       10000 non-null  float64
#  2   Internships                10000 non-null  int64
#  3   Projects                   10000 non-null  int64
#  4   Workshops/Certifications   10000 non-null  int64
#  5   AptitudeTestScore          10000 non-null  int64
#  6   SoftSkillsRating           10000 non-null  float64
#  7   ExtracurricularActivities  10000 non-null  object
#  8   PlacementTraining          10000 non-null  object
#  9   SSC_Marks                  10000 non-null  int64
#  10  HSC_Marks                  10000 non-null  int64
#  11  PlacementStatus            10000 non-null  object
# dtypes: float64(2), int64(7), object(3)
# memory usage: 937.6+ KB

# %%
df.describe()
# Out:
#          StudentID          CGPA   Internships      Projects  \
# count  10000.00000  10000.000000  10000.000000  10000.000000
# mean    5000.50000      7.698010      1.049200      2.026600
# std     2886.89568      0.640131      0.665901      0.867968
# min        1.00000      6.500000      0.000000      0.000000
# 25%     2500.75000      7.400000      1.000000      1.000000
# 50%     5000.50000      7.700000      1.000000      2.000000
# 75%     7500.25000      8.200000      1.000000      3.000000
# max    10000.00000      9.100000      2.000000      3.000000
#
#        Workshops/Certifications  AptitudeTestScore  SoftSkillsRating  \
# count              10000.000000       10000.000000      10000.000000
# mean                   1.013200          79.449900          4.323960
# std                    0.904272           8.159997          0.411622
# min                    0.000000          60.000000          3.000000
# ...

# %%
df.isnull().sum()
# Out:
# StudentID                    0
# CGPA                         0
# Internships                  0
# Projects                     0
# Workshops/Certifications     0
# AptitudeTestScore            0
# SoftSkillsRating             0
# ExtracurricularActivities    0
# PlacementTraining            0
# SSC_Marks                    0
# HSC_Marks                    0
# PlacementStatus              0
# dtype: int64

# %%
df.shape
# Out:
# (10000, 12)

# %%
df.columns
# Out:
# Index(['StudentID', 'CGPA', 'Internships', 'Projects',
#        'Workshops/Certifications', 'AptitudeTestScore', 'SoftSkillsRating',
#        'ExtracurricularActivities', 'PlacementTraining', 'SSC_Marks',
#        'HSC_Marks', 'PlacementStatus'],
#       dtype='object')

# %%
data=df.drop('SSC_Marks',axis = 1,inplace = True)

# %%
data1=df.drop('HSC_Marks',axis = 1,inplace = True)

# %%
df
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0             1   7.5            1         1                         1
# 1             2   8.9            0         3                         2
# 2             3   7.3            1         2                         2
# 3             4   7.5            1         1                         2
# 4             5   8.3            1         2                         2
# ...         ...   ...          ...       ...                       ...
# 9995       9996   7.5            1         1                         2
# 9996       9997   7.4            0         1                         0
# 9997       9998   8.4            1         3                         0
# 9998       9999   8.9            0         3                         2
# 9999      10000   8.4            0         1                         1
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# ...

# %%
df.rename(columns = {'ExtracurricularActivities':'Extra Activities'},inplace=True)
df
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0             1   7.5            1         1                         1
# 1             2   8.9            0         3                         2
# 2             3   7.3            1         2                         2
# 3             4   7.5            1         1                         2
# 4             5   8.3            1         2                         2
# ...         ...   ...          ...       ...                       ...
# 9995       9996   7.5            1         1                         2
# 9996       9997   7.4            0         1                         0
# 9997       9998   8.4            1         3                         0
# 9998       9999   8.9            0         3                         2
# 9999      10000   8.4            0         1                         1
#
#       AptitudeTestScore  SoftSkillsRating Extra Activities PlacementTraining  \
# ...

# %%
df.columns
# Out:
# Index(['StudentID', 'CGPA', 'Internships', 'Projects',
#        'Workshops/Certifications', 'AptitudeTestScore', 'SoftSkillsRating',
#        'Extra Activities', 'PlacementTraining', 'PlacementStatus'],
#       dtype='object')

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder()
ohe
# Out:
# OneHotEncoder()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
le
# Out:
# LabelEncoder()

# %%
df['Extra Activities'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
le.fit(df['Extra Activities'])
# Out:
# LabelEncoder()

# %%
le.transform(df['Extra Activities'])
# Out:
# array([0, 1, 1, ..., 1, 1, 0], shape=(10000,))

# %%
df['Extra Activities'] = le.transform(df['Extra Activities'])

# %%
df.head()
# Out:
#    StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0          1   7.5            1         1                         1
# 1          2   8.9            0         3                         2
# 2          3   7.3            1         2                         2
# 3          4   7.5            1         1                         2
# 4          5   8.3            1         2                         2
#
#    AptitudeTestScore  SoftSkillsRating  Extra Activities PlacementTraining  \
# 0                 65               4.4                 0                No
# 1                 90               4.0                 1               Yes
# 2                 82               4.8                 1                No
# 3                 85               4.4                 1               Yes
# 4                 86               4.5                 1               Yes
#
#   PlacementStatus
# 0       NotPlaced
# 1          Placed
# 2       NotPlaced
# 3          Placed
# ...

# %%
le.fit(df['PlacementTraining'])
# Out:
# LabelEncoder()

# %%
le.fit(df['PlacementTraining'])
# Out:
# array([0, 1, 0, ..., 1, 1, 0], shape=(10000,))

# %%
df['PlacementTraining'] = le.transform(df['PlacementTraining'])

# %%
df.head()
# Out:
#    StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0          1   7.5            1         1                         1
# 1          2   8.9            0         3                         2
# 2          3   7.3            1         2                         2
# 3          4   7.5            1         1                         2
# 4          5   8.3            1         2                         2
#
#    AptitudeTestScore  SoftSkillsRating  Extra Activities  PlacementTraining  \
# 0                 65               4.4                 0                  0
# 1                 90               4.0                 1                  1
# 2                 82               4.8                 1                  0
# 3                 85               4.4                 1                  1
# 4                 86               4.5                 1                  1
#
#   PlacementStatus
# 0       NotPlaced
# 1          Placed
# 2       NotPlaced
# 3          Placed
# ...

# %%
le.fit(df['PlacementStatus'])
le.transform(df['PlacementStatus'])
# Out:
# array([0, 1, 0, ..., 1, 1, 0], shape=(10000,))

# %%
df['PlacementStatus'] = le.transform(df['PlacementStatus'])
df.head()
# Out:
#    StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0          1   7.5            1         1                         1
# 1          2   8.9            0         3                         2
# 2          3   7.3            1         2                         2
# 3          4   7.5            1         1                         2
# 4          5   8.3            1         2                         2
#
#    AptitudeTestScore  SoftSkillsRating  Extra Activities  PlacementTraining  \
# 0                 65               4.4                 0                  0
# 1                 90               4.0                 1                  1
# 2                 82               4.8                 1                  0
# 3                 85               4.4                 1                  1
# 4                 86               4.5                 1                  1
#
#    PlacementStatus
# 0                0
# 1                1
# 2                0
# ...

# %%
x = df.drop('PlacementStatus',axis=1)
y = df['PlacementStatus']

# %%
x.head()
# Out:
#    StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0          1   7.5            1         1                         1
# 1          2   8.9            0         3                         2
# 2          3   7.3            1         2                         2
# 3          4   7.5            1         1                         2
# 4          5   8.3            1         2                         2
#
#    AptitudeTestScore  SoftSkillsRating  Extra Activities  PlacementTraining
# 0                 65               4.4                 0                  0
# 1                 90               4.0                 1                  1
# 2                 82               4.8                 1                  0
# 3                 85               4.4                 1                  1
# 4                 86               4.5                 1                  1

# %% [markdown]
# y.head()

# %%
###when test_size=0.3 and random_state=42###
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.3,random_state=42)
print("x_train ",x_train.shape)
print("x_test ",x_test.shape)
print("y_train ",y_train.shape)
print("y_test ",y_test.shape)
# Out:
# x_train  (7000, 9)
# x_test  (3000, 9)
# y_train  (7000,)
# y_test  (3000,)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 0.05752912,  0.34369101, -0.19855754, ...,  0.90497538,
#         0.3692428 ,  0.07505461], shape=(3000,))

# %%
print("Coefficients:", model.coef_)
print("Intercept:",model.intercept_)
# Out:
# Coefficients: [-2.93189640e-06  7.80661543e-02  1.48125876e-02  7.26916290e-02
#   4.26558083e-02  1.30147360e-02  1.15507106e-01  1.56461662e-01
#   1.16633011e-01]
# Intercept: -2.0817887246876645

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test,y_pred)
print("mean_squared_error",mse)
# Out:
# mean_squared_error 0.14686563473826095

# %%
from sklearn.metrics import root_mean_squared_error
rmse =  root_mean_squared_error(y_test,y_pred)
print("root_mean_squared_error",rmse)
# Out:
# root_mean_squared_error 0.38323052427783066

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test,y_pred)
print("mean_absolute_error",mae)
# Out:
# mean_absolute_error 0.3133822894864029

# %%
###when test_size=0.3 and random_state=60###
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.3,random_state=60)
print("x_train ",x_train.shape)
print("x_test ",x_test.shape)
print("y_train ",y_train.shape)
print("y_test ",y_test.shape)
# Out:
# x_train  (7000, 9)
# x_test  (3000, 9)
# y_train  (7000,)
# y_test  (3000,)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 0.01990582,  0.37768296,  0.05258942, ..., -0.11019324,
#         0.36840254,  0.04516564], shape=(3000,))

# %%
print("Coefficients:", model.coef_)
print("Intercept:",model.intercept_)
# Out:
# Coefficients: [-9.09419400e-07  7.67328219e-02  1.38274048e-02  7.51462711e-02
#   5.01132639e-02  1.25579440e-02  1.13077426e-01  1.51768440e-01
#   1.15154877e-01]
# Intercept: -2.0444045676478835

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test,y_pred)
print("mean_squared_error",mse)
# Out:
# mean_squared_error 0.1465664813654192

# %%
from sklearn.metrics import root_mean_squared_error
rmse =  root_mean_squared_error(y_test,y_pred)
print("root_mean_squared_error",rmse)
# Out:
# root_mean_squared_error 0.38284002059008826

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test,y_pred)
print("mean_absolute_error",mae)
# Out:
# mean_absolute_error 0.31360058764379733

# %%
###when test_size=0.2 and random_state=60###
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2,random_state=60)
print("x_train ",x_train.shape)
print("x_test ",x_test.shape)
print("y_train ",y_train.shape)
print("y_test ",y_test.shape)
# Out:
# x_train  (8000, 9)
# x_test  (2000, 9)
# y_train  (8000,)
# y_test  (2000,)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([0.02181378, 0.38292427, 0.05199994, ..., 0.43169271, 0.15109171,
#        0.65627693], shape=(2000,))

# %%
print("Coefficients:", model.coef_)
print("Intercept:",model.intercept_)
# Out:
# Coefficients: [-7.46453438e-07  8.06948287e-02  1.12605642e-02  7.25689619e-02
#   4.55241862e-02  1.27815569e-02  1.05410477e-01  1.56867505e-01
#   1.18757492e-01]
# Intercept: -2.0536111149324054

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test,y_pred)
print("mean_squared_error",mse)
# Out:
# mean_squared_error 0.14489883604094195

# %%
from sklearn.metrics import root_mean_squared_error
rmse =  root_mean_squared_error(y_test,y_pred)
print("root_mean_squared_error",rmse)
# Out:
# root_mean_squared_error 0.38065579733000515

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test,y_pred)
print("mean_absolute_error",mae)
# Out:
# mean_absolute_error 0.31306001318508975

# %%
###when test_size=0.2 and random_state=42###
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2,random_state=42)
print("x_train ",x_train.shape)
print("x_test ",x_test.shape)
print("y_train ",y_train.shape)
print("y_test ",y_test.shape)
# Out:
# x_train  (8000, 9)
# x_test  (2000, 9)
# y_train  (8000,)
# y_test  (2000,)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
y_pedict=model.predict(x_test)
y_pred
# Out:
# array([0.02181378, 0.38292427, 0.05199994, ..., 0.43169271, 0.15109171,
#        0.65627693], shape=(2000,))

# %%
print("Coefficients:", model.coef_)
print("Intercept:",model.intercept_)
# Out:
# Coefficients: [-1.83622005e-06  8.04055011e-02  1.43785339e-02  7.52551498e-02
#   4.12114333e-02  1.28210718e-02  1.19415420e-01  1.55923759e-01
#   1.13823256e-01]
# Intercept: -2.1079109310651316

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test,y_pred)
print("mean_squared_error",mse)
# Out:
# mean_squared_error 0.32830747727710996

# %%
from sklearn.metrics import root_mean_squared_error
rmse =  root_mean_squared_error(y_test,y_pred)
print("root_mean_squared_error",rmse)
# Out:
# root_mean_squared_error 0.5729812189567036

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test,y_pred)
print("mean_absolute_error",mae)
# Out:
# mean_absolute_error 0.4896745572257707

# %%
###when test_size=0.2 and random_state=0###
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2,random_state=0)
print("x_train ",x_train.shape)
print("x_test ",x_test.shape)
print("y_train ",y_train.shape)
print("y_test ",y_test.shape)
# Out:
# x_train  (8000, 9)
# x_test  (2000, 9)
# y_train  (8000,)
# y_test  (2000,)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
y_pedict=model.predict(x_test)
y_pred
# Out:
# array([0.02181378, 0.38292427, 0.05199994, ..., 0.43169271, 0.15109171,
#        0.65627693], shape=(2000,))

# %%
print("Coefficients:", model.coef_)
print("Intercept:",model.intercept_)
# Out:
# Coefficients: [-5.64419386e-07  7.48112344e-02  1.35689384e-02  7.44040753e-02
#   4.12058376e-02  1.25871342e-02  1.14122062e-01  1.72174202e-01
#   1.13580595e-01]
# Intercept: -2.03605781056511

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test,y_pred)
print("mean_squared_error",mse)
# Out:
# mean_squared_error 0.3302290938828919

# %%
from sklearn.metrics import root_mean_squared_error
rmse =  root_mean_squared_error(y_test,y_pred)
print("root_mean_squared_error",rmse)
# Out:
# root_mean_squared_error 0.574655630689278

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test,y_pred)
print("mean_absolute_error",mae)
# Out:
# mean_absolute_error 0.4920847887074974
